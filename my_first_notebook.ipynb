# %% [markdown]
# The parts of a computer that you can see and touch, like a keyboard, mouse, or monitor, are called hardware. In contrast, software is made up of programs and instructions that inform the hardware how to do tasks. For example, a keyboard is hardware, but Microsoft Word is software for document creation. Hardware cannot work without software, and software need hardware to operate. They work together to ensure that a computer system runs efficiently.
