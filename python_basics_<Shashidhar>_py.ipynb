# %% [markdown]
# <a href="https://colab.research.google.com/github/shashidharkandula369/my_first_repo/blob/main/python_basics_%3CShashidhar%3E_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Task-1
name = "Shashidhar"
age = 24
height = 1.75
is_student = True
print(name,age,height,is_student)

#Task-2

print(f"Name:{name}, Age:{age} , Height:{height} , Student:{is_student}")

#Task-3
age_months = age * 12
age_days = age * 365
age_reminder = age % 7
age_power = age ** 2

print("-----Arithmetic Operations of Age-----")
print("Age in months:",age_months)
print("age_months:",age_days)
print("The remainder when age is divided by 7:",age_reminder)
print("Age raised to the power of 2:",age_power)
# Out:
# Shashidhar 24 1.75 True
# Name:Shashidhar, Age:24 , Height:1.75 , Student:True
# -----Arithmetic Operations of Age-----
# Age in months: 288
# age_months: 8760
# The remainder when age is divided by 7: 3
# Age raised to the power of 2: 576
